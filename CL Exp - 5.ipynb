# %%
import pandas as pd
import numpy as np

df = pd.read_csv('CovidIndiaData-01-04-2020.csv')
pd.read_csv('CovidIndiaData-01-04-2020.csv')
# Out:
#     Confirmed CountryReg  Deaths  LastUpdate   Latitude  Longitude  Province
# 0           1      India       0  2020-01-30   0.000000    0.00000         0  \
# 1           1      India       0  2020-01-31   0.000000    0.00000         0
# 2           1      India       0  2020-01-31   0.000000    0.00000         0
# 3           2      India       0  2020-02-02   0.000000    0.00000         0
# 4           3      India       0  2020-02-03   0.000000    0.00000         0
# ..        ...        ...     ...         ...        ...        ...       ...
# 57        887      India      20  2020-03-27  20.593684   78.96288         0
# 58        987      India      24  2020-03-28  20.593684   78.96288         0
# 59       1024      India      27  2020-03-29  20.593684   78.96288         0
# 60       1251      India      32  2020-03-30  20.593684   78.96288         0
# 61       1397      India      35  2020-03-31  20.593684   78.96288         0
#
# ...

# %%
print("The mean of Confirmed:", df["Confirmed"].mean())
print("The mean of Deaths:", df["Deaths"].mean())
print("The mean of Recovered:", df["Recovered"].mean())
print("The mean of week:", df["week"].mean())
# Out:
# The mean of Confirmed: 166.74193548387098
# The mean of Deaths: 3.6451612903225805
# The mean of Recovered: 13.983870967741936
# The mean of week: 8.96774193548387

# %%
print("The median of Confirmed:", df["Confirmed"].median())
print("The median of Deaths:", df["Deaths"].median())
print("The median of Recovered:", df["Recovered"].median())
print("The median of week:", df["week"].median())
# Out:
# The median of Confirmed: 3.0
# The median of Deaths: 0.0
# The median of Recovered: 3.0
# The median of week: 7.0

# %%
print("The mode of Confirmed:", df["Confirmed"].mode())
print("The mode of Deaths:", df["Deaths"].mode())
print("The mode of Recovered:", df["Recovered"].mode())
print("The mode of week:", df["week"].mode())
# Out:
# The mode of Confirmed: 0    3
# Name: Confirmed, dtype: int64
# The mode of Deaths: 0    0
# Name: Deaths, dtype: int64
# The mode of Recovered: 0    3
# Name: Recovered, dtype: int64
# The mode of week: 0    7
# Name: week, dtype: int64

# %%
print("The standard deviation of Confirmed:", df["Confirmed"].std())
print("The standard deviation of Deaths:", df["Deaths"].std())
print("The standard deviation of Recovered:", df["Recovered"].std())
print("The standard deviation of week:", df["week"].std())
# Out:
# The standard deviation of Confirmed: 328.18566993439987
# The standard deviation of Deaths: 8.114138185793308
# The standard deviation of Recovered: 26.963540614594386
# The standard deviation of week: 2.8224378599527307

# %%
print("The variance of Confirmed:", df["Confirmed"].var())
print("The variance of Deaths:", df["Deaths"].var())
print("The variance of Recovered:", df["Recovered"].var())
print("The variance of week:", df["week"].var())
# Out:
# The variance of Confirmed: 107705.83395029085
# The variance of Deaths: 65.83923849814913
# The variance of Recovered: 727.032522474881
# The variance of week: 7.966155473294551
