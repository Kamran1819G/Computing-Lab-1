# %% [markdown]
# # Experiment No: 9

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import html

driver = webdriver.Chrome('chromedriver')
products=[] 
prices=[] 
discounts=[]

driver.get("https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_3_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_3_6_na_na_na&as-pos=3&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=85ca63a2-17fa-4d0a-8cb5-7a7b522347a8&as-searchtext=laptop")

content = driver.page_source
soup = BeautifulSoup(content)

for a in soup.findAll('a',href=True, attrs={'class':'_1fQZEK'}):
    name=a.find('div', attrs={'class':'_4rR01T'})
    price=a.find('div', attrs={'class':'_30jeq3 _1_WHN1'})
    discount=a.find('div', attrs={'class':'_3Ay6Sb'})
    products.append(name.text)
    prices.append(price.text)
    discounts.append(discount.text)
    
df = pd.DataFrame({'Product Name':products,'Price':prices,'Discounts':discounts}) 
df.to_csv('products.csv', index=False, encoding='utf-8')

# %%
pd.read_csv('products.csv')
# Out:
#                                          Product Name      Price Discounts
# 0   HP Laptop Core i3 11th Gen - (8 GB/512 GB SSD/...    ₹39,990   18% off
# 1   HP Intel Core i5 11th Gen - (8 GB/512 GB SSD/W...    ₹53,490   11% off
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...    ₹35,990   29% off
# 3   ASUS VivoBook 14 (2021) Celeron Dual Core - (4...    ₹21,990   35% off
# 4   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...    ₹45,990   34% off
# 5   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...    ₹33,490   43% off
# 6   Infinix INBook X2 Plus Core i5 11th Gen - (16 ...    ₹41,990   30% off
# 7   ASUS TUF Dash F15 (2022) Core i5 12th Gen - (8...    ₹73,990   28% off
# 8   RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...    ₹41,990   30% off
# 9   HP 14s Intel Core i3 11th Gen - (8 GB/512 GB S...    ₹40,490   18% off
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...    ₹16,990   32% off
# 11  ASUS Vivobook Pro 15 Ryzen 7 Octa Core AMD R7-...    ₹59,990   27% off
# 12  ASUS TUF Gaming A15 Ryzen 5 Hexa Core AMD R5-4...    ₹54,990   27% off
# 13  ASUS Vivobook 15 Core i7 11th Gen - (16 GB/512...    ₹56,990   29% off
# 14  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹54,990   26% off
# 15  MSI Bravo 15 Ryzen 7 Octa Core 5800H - (16 GB/...    ₹62,990   13% off
# 16  ASUS Vivobook K15 OLED Ryzen 5 Hexa Core AMD R...    ₹50,990   37% off
# 17  HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...    ₹44,490   20% off
# 18  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...    ₹46,949   31% off
# 19  ASUS Vivobook Pro 15 Ryzen 7 Octa Core AMD R7-...    ₹59,990   27% off
# 20  ASUS VivoBook K15 OLED Ryzen 5 Hexa Core AMD R...    ₹50,990   37% off
# 21  HP Pavilion Intel Core i5 12th Gen - (16 GB/51...    ₹66,999   16% off
# 22  Infinix INBook Y1 Plus Intel Core i3 10th Gen ...    ₹30,490   39% off
# 23  DELL Core i5 12th Gen - (16 GB/512 GB SSD/Wind...  ₹1,10,490   22% off

# %% [markdown]
# ![image.png](attachment:image.png)
